# %%
import glob                      
from scipy.stats import pearsonr 
import pandas as pd              
import matplotlib.pyplot as plt 
import numpy as np              
from sqlalchemy import create_engine

# %%
# List of files

filesList = glob.glob("C:\\Users\\Portales Ely\\Desktop\\resources_proyecto\\*.csv")

# %%
list_data = []

# %%
# Loop thru files
for files in filesList:
    data = pd.read_csv(files)
    list_data.append(data)

# %%
list_dt= pd.DataFrame(columns=('RFC', 'RAZON SOCIAL','SUPUESTO'))

# %%
# Out:
# C:\Users\Portales Ely\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
list_dt
# Out:
#                RFC                                       RAZON SOCIAL  \
# 0     &ME060209E41                              Y & Y MEXICO SA DE CV
# 1     &ML040319NR4                   E & M LOGISTIC SERVICE  SA DE CV
# 2     &RM040614KE0                      A & R DE MEXICO .925 SA DE CV
# 3     A&A040416LQA  ATTORNEYS & ATTORNEYS CORPORATIVO JURIDICO FIS...
# 4     A&A0505218T0           ARVAYO & ASOCIADOS CARPENTER' S SA DE CV
# 5     A&C060911JC0            AVALOS & CHAVEZ CONSULTORES FISCALES SC
# 6     A&L0310081E8                              ARCHIBAL & LICEAGA SC
# 7     A&M041111A67                          ART & MAÑA CONSULTORES SC
# 8     A&M050224EX3         ARMENDARIZ & MICHEL CONSULTORES LEGALES SC
# 9     A&M0507202B5                              ADAM & MEYER SA DE CV
# 10    A&M9701282T6                          ALEXANDER & MARY SA DE CV
# 11    A&R060721RD5    ARIAS & REYES INGENIEROS Y ARQUITECTOS SA DE CV
# ...

# %%
list_dt.rename({'RFC': 'rfc', 'RAZON SOCIAL': 'razon_social', 'SUPUESTO' : 'supuesto'}, axis=1, inplace=True)
list_dt
# Out:
#                rfc                                       razon_social  \
# 0     &ME060209E41                              Y & Y MEXICO SA DE CV
# 1     &ML040319NR4                   E & M LOGISTIC SERVICE  SA DE CV
# 2     &RM040614KE0                      A & R DE MEXICO .925 SA DE CV
# 3     A&A040416LQA  ATTORNEYS & ATTORNEYS CORPORATIVO JURIDICO FIS...
# 4     A&A0505218T0           ARVAYO & ASOCIADOS CARPENTER' S SA DE CV
# 5     A&C060911JC0            AVALOS & CHAVEZ CONSULTORES FISCALES SC
# 6     A&L0310081E8                              ARCHIBAL & LICEAGA SC
# 7     A&M041111A67                          ART & MAÑA CONSULTORES SC
# 8     A&M050224EX3         ARMENDARIZ & MICHEL CONSULTORES LEGALES SC
# 9     A&M0507202B5                              ADAM & MEYER SA DE CV
# 10    A&M9701282T6                          ALEXANDER & MARY SA DE CV
# 11    A&R060721RD5    ARIAS & REYES INGENIEROS Y ARQUITECTOS SA DE CV
# ...

# %%
connection_string="postgresql://postgres:1234@localhost:5432/shcp"
engine = create_engine(connection_string)

# %%
engine.table_names()
# Out:
# ['shcp']

# %%
list_dt.to_sql(name="shcp", con=engine, if_exists="append",index=False)
